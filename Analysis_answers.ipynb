# %% [markdown]
# 1) Does trip distance significantly affect fare amount?
#
#  No. The Trip distance does not significantly affent the Fare Amount.
#  ![image.png](attachment:image.png)
#
#  The Pearson Correlation matrix helps us to iddentify if two variables are interrelated or not. Here, it shows that the Correlation value for Trip distance and Fare Amount is positive, but very near to Zero. Hence, There is no Strong correlation between them. We can conclude saying that Trip distance does not significantly affect fare amount

# %% [markdown]
# 2) Are premium rides statistically more expensive than economy rides?
#
# As per the results of t-test, we can say that there is no statistical evidence that Premium rides are more Expensive than Economy rides.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. Is there a relationship between surge pricing and customer ratings?
#
# ![image.png](attachment:image.png)
#
# The relationship between surge pricing and customer ratings is negative telling that they are inversely related. If surge pricing increases then customer ratings decreases. But the value is very near to Zero. Meaning the correlation is very weak.

# %% [markdown]
# 4) Do peak-hour rides differ in revenue compared to non-peak rides?
#
# Using z-test results
#
# ![image.png](attachment:image.png)
#
# The z-test was performed for fare amount and Ride_time columns. The testing concludes by saying that there is no significance difference fare amount between peak and non-peak rides.

# %% [markdown]
# 5) Are there unusual fare values that indicate anomalies or pricing errors?
#
# The outlier dectection was coducted using the Percentile, IQR and Z-score methods.
# The Z-score method showed 0 outliers
# The IQR method showed one oulier value 37. Which was then removed.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 6) Can ride demand probabilities be estimated for different ride categories?
#
# Ride demand probabilities were estimated using basic probability, conditional probability, and Bayes' Theorem. The probability of a ride being Premium given that it occurred during Peak hours was 31.07%. These probability estimates help understand customer preferences and can support demand forecasting and pricing decisions.

# %% [markdown]
# 7) Which operational factors are most strongly related to business performance?
#
# Pearson and Spearman correlation analyses revealed very weak relationships among the operational variables. The highest positive correlation was observed between Fare Amount and Customer Rating (r = 0.047), while the strongest negative correlation was between Trip Distance and Customer Rating (r = -0.082). Since all correlation coefficients were close to zero, none of the operational factors showed a strong association with business performance.
#
# Covariance analysis similarly indicated limited joint variation among the variables. Furthermore, eigenvalue analysis produced a determinant of 0.9874 and eigenvalues close to 1, suggesting very low multicollinearity and that no single factor dominates the dataset.
#
# Therefore, business performance appears to be influenced by multiple independent operational factors rather than one strongly dominant variable.

# %% [markdown]
# 8) Can statistical evidence support pricing or service improvements?
#
# Statistical evidence can support both pricing and service improvement decisions. A bootstrap analysis of Fare_Amount produced a 95% confidence interval of [248.9572843185668 270.7022623745916], indicating a reliable estimate of the average Fare Amount. Confidence interval estimation also provided a plausible range for the population mean, helping management make decisions based on expected operational performance rather than individual observations.
#
# Hypothesis testing was used to evaluate whether meaningful differences existed between customer groups and operational conditions. The independent t-test and ANOVA comparing Premium and Economy rides can be used to determine whether premium pricing is justified by significantly higher fares. Similarly, tests comparing Peak and Non-Peak rides help assess whether demand-based pricing strategies are effective.
#
# The Chi-Square test showed no significant relationship between Ride Category and Ride Time (p = 0.4769), suggesting that customer ride-category choices are relatively stable across peak and non-peak periods. Correlation analysis also revealed only weak relationships among operational variables, indicating that pricing and service decisions should not rely on a single factor.
#
# Overall, the statistical evidence supports using data-driven pricing policies, monitoring customer behavior, and continuously evaluating service performance through confidence intervals, bootstrapping, and hypothesis testing. These methods provide objective evidence for making operational and pricing improvements while reducing uncertainty in decision-making.
